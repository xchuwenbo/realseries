# %%
import sys
import os
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# solution for relative imports in case realseries is not installed
sys.path.append('/home/cuipeng/realseries')
import argparse
from realseries.models.mc_dropout import MC_dropout
from realseries.utils.data import load_exp_data

# %%
data_name = 'air_quality'
fractions= [0.6,0.2,0.2]
window_size = 7
prediction_window_size = 1

# %%
data_dir = os.path.join('../examples/exp_data/')
data_path = data_dir + data_name + '.csv'
data = pd.read_csv(data_path)
data.head()
# Out:
#    CO(GT)  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)  NO2(GT)  PT08.S3(NOx)  \
# 0     2.7       1280.0       9.6          964.0    113.0         963.0
# 1     1.9       1196.0       7.4          873.0     97.0        1071.0
# 2     1.6       1184.0       5.4          782.0     82.0        1176.0
# 3     1.7       1172.0       5.4          783.0    109.0        1179.0
# 4     1.8       1147.0       6.2          821.0     83.0        1132.0
#
#    PT08.S4(NO2)  PT08.S5(O3)    RH      AH  NOx(GT)
# 0        1544.0       1285.0  64.1  0.7597    193.0
# 1        1463.0       1144.0  63.9  0.7423    139.0
# 2        1365.0       1043.0  63.9  0.7256     83.0
# 3        1380.0        996.0  67.5  0.7173    180.0
# 4        1412.0        992.0  71.1  0.7158    109.0

# %%
# load raw data and get train data, validation data and test data
train_data, train_label, test_data, test_label, val_data, val_label, sc = load_exp_data(data_name, window_size, prediction_window_size, fractions)
# Out:
# load data from /home/cuipeng/realseries/realseries/utils/../../examples/exp_data/air_quality.csv

# %%
print(train_data.shape,train_label.shape)
# Out:
# (5577, 7, 11) (5577, 1)

# %%
plt.figure()
plt.plot(train_label)
plt.suptitle('scaling train label')
# Out:
# Text(0.5, 0.98, 'scaling train label')

# %%
inversed = sc.inverse_transform(np.concatenate((train_data.reshape(train_data.shape[0],-1),train_label),1))
train_label_raw = inversed[:,-train_label.shape[1]:]
plt.plot(train_label_raw)
plt.suptitle('raw train label')
# Out:
# Text(0.5, 0.98, 'raw train label')

# %%
# start building the MC_dropout model
kernel_type ='LSTM'
activation ='tanh'
dropout_rate = 0.3
hiddens = [128,32]
my_mc_model = MC_dropout(kernel_type, train_data.shape[-1], hiddens, prediction_window_size, activation, dropout_rate, epochs=1000, variance=False)

# %%
# next to fit the model
my_mc_model.fit(train_data, train_label, val_data, val_label,verbose=False)
# Out:
# epoch: 20 -> train_loss: 0.01319, valid_loss: 0.01422
# epoch: 40 -> train_loss: 0.00986, valid_loss: 0.01068
# epoch: 60 -> train_loss: 0.00891, valid_loss: 0.00982
# epoch: 80 -> train_loss: 0.00831, valid_loss: 0.00915
# epoch: 100 -> train_loss: 0.00783, valid_loss: 0.00865
# epoch: 120 -> train_loss: 0.00734, valid_loss: 0.00809
# epoch: 140 -> train_loss: 0.00689, valid_loss: 0.00763
# epoch: 160 -> train_loss: 0.00651, valid_loss: 0.00722
# epoch: 180 -> train_loss: 0.00637, valid_loss: 0.00705
# epoch: 200 -> train_loss: 0.00616, valid_loss: 0.00691
# saving the model to model/checkpoint200.pt
# epoch: 220 -> train_loss: 0.00605, valid_loss: 0.00663
# epoch: 240 -> train_loss: 0.00605, valid_loss: 0.00657
# epoch: 260 -> train_loss: 0.00591, valid_loss: 0.00633
# epoch: 280 -> train_loss: 0.00582, valid_loss: 0.00646
# epoch: 300 -> train_loss: 0.00581, valid_loss: 0.00618
# epoch: 320 -> train_loss: 0.00582, valid_loss: 0.00630
# epoch: 340 -> train_loss: 0.00577, valid_loss: 0.00621
# epoch: 360 -> train_loss: 0.00571, valid_loss: 0.00612
# epoch: 380 -> train_loss: 0.00570, valid_loss: 0.00620
# epoch: 400 -> train_loss: 0.00566, valid_loss: 0.00618
# saving the model to model/checkpoint400.pt
# epoch: 420 -> train_loss: 0.00565, valid_loss: 0.00598
# epoch: 440 -> train_loss: 0.00556, valid_loss: 0.00599
# epoch: 460 -> train_loss: 0.00563, valid_loss: 0.00602
# epoch: 480 -> train_loss: 0.00553, valid_loss: 0.00608
# epoch: 500 -> train_loss: 0.00557, valid_loss: 0.00604
# epoch: 520 -> train_loss: 0.00553, valid_loss: 0.00605
# epoch: 540 -> train_loss: 0.00541, valid_loss: 0.00595
# epoch: 560 -> train_loss: 0.00551, valid_loss: 0.00603
# Early stopping
# saving the model to model/checkpoint.pt

# %%
# save the trained model
my_mc_model.save_model()
# Out:
# saving the model to model/checkpoint.pt

# %%
# load the model and forecast
my_mc_model.load_model()
confidence = 95
# return the lower bound and the upper bound arrays of the predictive intervals for test data
pi_low, pi_up, rmse, cali_error = my_mc_model.evaluation_model(sc, test_data, test_label, t=1, confidence = confidence, mc_times=1000)
print('rmse:{}, calibration error:{}'.format(rmse, cali_error))
# Out:
# loading model/checkpoint.pt
# rmse:110.83307647705078, calibration error:0.654

# %%
# Out:
# (1859, 1)

# %%
inversed = sc.inverse_transform(np.concatenate((test_data.reshape(test_data.shape[0],-1),test_label),1))
test_label_raw = inversed[:,-test_label.shape[1]:]

# %%
x_temp = [_ for _ in range(100)]
pi_low, pi_up = pi_low.reshape(pi_low.shape[0],), pi_up.reshape(pi_up.shape[0],)
plt.figure(dpi=100)
plt.plot(test_label_raw[0:100], marker='o',ms = 4, lw=1.5, label = 'Ground Truth')
plt.fill_between(x_temp, pi_low[0:100], pi_up[0:100],label = "95% PIs", alpha=0.5, color='#D2691E')
